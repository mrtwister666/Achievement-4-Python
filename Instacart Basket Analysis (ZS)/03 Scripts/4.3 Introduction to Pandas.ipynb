# %%
import pandas as pd
import numpy as np
import os

# %%
path='/Users/z/Documents/CF/Unit 1/4. Python Fundamentals for Data Analysts /06-2023-Instacart Basket Analysis'

# %%
df=pd.read_csv(os.path.join(path,'02 Data','Original data', 'orders.csv'), nrows=1000)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   order_id                1000 non-null   int64
#  1   user_id                 1000 non-null   int64
#  2   eval_set                1000 non-null   object
#  3   order_number            1000 non-null   int64
#  4   order_dow               1000 non-null   int64
#  5   order_hour_of_day       1000 non-null   int64
#  6   days_since_prior_order  936 non-null    float64
# dtypes: float64(1), int64(5), object(1)
# memory usage: 54.8+ KB

# %%
vars_list=['order_id','user_id','order_number','order_dow','order_hour_of_day','days_since_prior_order']

# %%
vars_list
# Out:
# ['order_id',
#  'user_id ',
#  'order_number',
#  'order_dow',
#  'order_hour_of_day',
#  'days_since_prior_order']

# %%
df = pd.read_csv(os.path.join(path, '02 Data', 'Original data', 'orders.csv'), usecols = vars_list)

# %%
df.head()
# Out:
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1             1          2                  8
# 1   2398795        1             2          3                  7
# 2    473747        1             3          3                 12
# 3   2254736        1             4          4                  7
# 4    431534        1             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
df_prods=pd.read_csv(os.path.join(path,'02 Data','Original data', 'products.csv'), nrows=1000)

# %%
df_prods.head(20)
# Out:
#     product_id                                       product_name  aisle_id  \
# 0            1                         Chocolate Sandwich Cookies        61
# 1            2                                   All-Seasons Salt       104
# 2            3               Robust Golden Unsweetened Oolong Tea        94
# 3            4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4            5                          Green Chile Anytime Sauce         5
# 5            6                                       Dry Nose Oil        11
# 6            7                     Pure Coconut Water With Orange        98
# 7            8                  Cut Russet Potatoes Steam N' Mash       116
# 8            9                  Light Strawberry Blueberry Yogurt       120
# 9           10     Sparkling Orange Juice & Prickly Pear Beverage       115
# 10          11                                  Peach Mango Juice        31
# ...

# %%
df_prods.tail(35)
# Out:
#      product_id                                      product_name  aisle_id  \
# 965         965             Maxtra Cartridge Water Filter Refills        87
# 966         966                                   Pear Hard Cider        27
# 967         967   Gluten Free Soft & Chewy Snicker Doodle Cookies         8
# 968         968                      Zipper Bags Sandwich - 50 CT        85
# 969         969                                 Petite Green Peas       116
# 970         970              Salmon and Tuna Formula Dry Cat Food        41
# 971         971                       Chicken Alfredo with Rotini        38
# 972         972                               Linguine No 7 Pasta       131
# 973         973                               8 X 6 Cutting Board        10
# 974         974              Organic 54% Cocoa Dark Chocolate Bar        45
# 975         975            Creamy Vanilla Soy Milk Frozen Dessert        37
# ...

# %%
df_prods.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product_id     1000 non-null   int64
#  1   product_name   995 non-null    object
#  2   aisle_id       1000 non-null   int64
#  3   department_id  1000 non-null   int64
#  4   prices         1000 non-null   float64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 39.2+ KB

# %%
len(df_prods)
# Out:
# 1000

# %%
df.describe()
# Out:
#            order_id       user_id  order_number     order_dow  \
# count  3.421083e+06  3.421083e+06  3.421083e+06  3.421083e+06
# mean   1.710542e+06  1.029782e+05  1.715486e+01  2.776219e+00
# std    9.875817e+05  5.953372e+04  1.773316e+01  2.046829e+00
# min    1.000000e+00  1.000000e+00  1.000000e+00  0.000000e+00
# 25%    8.552715e+05  5.139400e+04  5.000000e+00  1.000000e+00
# 50%    1.710542e+06  1.026890e+05  1.100000e+01  3.000000e+00
# 75%    2.565812e+06  1.543850e+05  2.300000e+01  5.000000e+00
# max    3.421083e+06  2.062090e+05  1.000000e+02  6.000000e+00
#
#        order_hour_of_day  days_since_prior_order
# count       3.421083e+06            3.214874e+06
# mean        1.345202e+01            1.111484e+01
# std         4.226088e+00            9.206737e+00
# min         0.000000e+00            0.000000e+00
# 25%         1.000000e+01            4.000000e+00
# 50%         1.300000e+01            7.000000e+00
# 75%         1.600000e+01            1.500000e+01
# ...

# %%
df_prods.describe()
# Out:
#         product_id     aisle_id  department_id       prices
# count  1000.000000  1000.000000    1000.000000  1000.000000
# mean    499.962000    68.072000      11.699000     7.685600
# std     288.388819    38.768412       5.886854     4.243211
# min       1.000000     1.000000       1.000000     1.000000
# 25%     250.750000    37.000000       7.000000     4.100000
# 50%     499.500000    69.000000      12.000000     7.200000
# 75%     749.250000   101.000000      17.000000    11.200000
# max     999.000000   134.000000      21.000000    24.300000

# %% [markdown]
# Maximum value of aisle_id - 134.000000
# Data type of department_id - int64
